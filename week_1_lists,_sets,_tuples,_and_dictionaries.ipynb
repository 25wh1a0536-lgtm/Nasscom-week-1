# %%
fruits.append('orange')
print("After appending:", fruits)
# Out:
# After appending: ['apple', 'banana', 'cherry', 'apple', 'orange']

# %%
fruits.remove('banana')
print("After removing banana:", fruits)


print("Number of fruits:", len(fruits))
# Out:
# After removing banana: ['apple', 'cherry', 'apple', 'orange']
# Number of fruits: 4

# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)


print("First fruit:", fruits[0])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple

# %%
dimensions = (10, 20, 30)
print("Tuple:", dimensions)
# Out:
# Tuple: (10, 20, 30)

# %%
print("Second element:", dimensions[1])
# Out:
# Second element: 20

# %%
unique_numbers = {1, 2, 3, 2, 1}
print("Set (no duplicates):", unique_numbers)
# Out:
# Set (no duplicates): {1, 2, 3}

# %%
unique_numbers.add(4)
print("After adding 4:", unique_numbers)
# Out:
# After adding 4: {1, 2, 3, 4}

# %%
unique_numbers.remove(2)
print("After remove 2:", unique_numbers)
# Out:
# After remove 2: {1, 3, 4}

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
student = {
    'name': 'Sreemai',
    'age': 18,
    'course': 'Python'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Sreemai', 'age': 18, 'course': 'Python'}

# %%
print("Student name:", student['name'])
# Out:
# Student name: Sreemai

# %%
student['grade'] = 'A'
print("After adding grade:", student)


del student['age']
print("After deleting age:", student)


for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Sreemai', 'age': 18, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Sreemai', 'course': 'Python', 'grade': 'A'}
# name: Sreemai
# course: Python
# grade: A

# %%
keys = ['id', 'name', 'marks']
values = [101, 'Sreemai', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'Sreemai', 'marks': 88}
